# %% [markdown]
# # [NLP] Assignment 1: Tokenization
#
# In this assignment, you need to tokenize the text of the Twitter(X) users posts(tweets). The assignment consists of two tasks. When you finish all the tasks, create a GitHub repository for this assignment (you can use this repo later for the other assignments) and submit this notebook in the repository. Leave `requirements.txt` file if your code requires additional installations. Submit the link to the repository in Moodle.
#
# The [data](https://drive.google.com/file/d/15x_wPAflvYQ2Xh38iNQGrqUIWLj5l5Nw/view?usp=share_link) contains 5 files whereby each contains 44 tweets. Each tweet is separated by a newline.

# %% [markdown]
# ## Task 1. Tokenize some tweets manually (20 points)
#
# As a first task you need to tokenize first 15 tweets from `file2` by hand. This will allow you to understand the problem from a linguistic point of view. The guidelines for tweet tokenization are as follows:
#
# - Each smiley is a separate token
# - Each hashtag is an individual token. Each user reference is an individual token
# - If a word has spaces between them then it is converted to a single token
# - All punctuations are individual tokens. This includes double-quotes and single quotes also
# - A URL is a single token
#
# Example of output
#
#     Input tweet
#     @xfranman Old age has made N A T O!
#
#     Tokenized tweet (separated by comma)
#     @xfranman , Old , age , has , made , NATO , !

# %% [markdown]
# Input tweet: \
# Camping in Maine for the weekend. Hey Dad, Mama Loves YOU: http://www.mamapalooza.com
#
# Output tweet: \
# Camping, in, Maine, for, the, weekend,., Hey, Dad,,, Mama, Loves, YOU,:, http://www.mamapalooza.com
#
# Input tweet: \
# Its american tradition bitch
#
# Output tweet: \
# Its, american, tradition, bitch
#
# Input tweet: \
# @ThroughTheVoid They love it! The only pleasure they get in life. I actually do that. I'm sure I hear a tiny squeak... Then louder ones
#
# Output tweet: \
# @ThroughTheVoid, They, love, it,!, The, only, pleasure, they, get, in, life,., I, actually, do, that,., I'm, sure, I, hear, a, tiny, squeak,.,.,., Then, louder, ones
#
# Input tweet: \
# " RT @latti: @AbsoHilare stop tweeting in church! Lol <--- ""I tweet because I'm happy, I tweet because I'm free"" LOL!"
#
# Output tweet: \
# ,", RT, @latti,:, @AbsoHilare, stop, tweeting, in, church,!, Lol, <,-,-,-, ",",I, tweet, because, I'm, happy,,, I, tweet, because, I'm, free,",", LOL,!,"
#
# Input tweet: \
# Samsung Mini S2 portable HDD graced with colors that perfectly match your tacky beach gear: Sammy's done it aga.. http://tinyurl.com/lb5p6m
#
# Output tweet: \
# Samsung, Mini, S2, portable, HDD, graced, with, colors, that, perfectly, match, your, tacky, beach, gear,:, Sammy's, done, it, aga,.,., http://tinyurl.com/lb5p6m
#
# Input tweet: \
# @dialloc congrats on finding your way over. it may be slow going at first. hang in there. it's kinda cool when u get up to speed.
#
# Output tweet: \
# @dialloc, congrats, on, finding, your, way, over,., it, may, be, slow, going, at, first,., hang, in, there,., it's, kinda, cool, when, u, get, up, to, speed,.
#
# Input tweet: \
# iPhone activation delays continue, Apple offers $30 http://twt.gs/l3Ki
#
# Output tweet: \
# iPhone, activation, delays, continue,,, Apple, offers, $30, http://twt.gs/l3Ki
#
# Input tweet: \
# RT @GoogleAtWork Gmail maximum attachment size now 25MB http://bit.ly/62mjw Nice!!!
#
# Output tweet: \
# RT, @GoogleAtWork, Gmail, maximum, attachment, size, now, 25MB, http://bit.ly/62mjw, Nice,!,!,!
# Input tweet:
#
# RT @acfou The Ads Won Awards for Crispin; But Did Nothing for Client BurgerKing's Sales/Marketshare - Big Surprise - http://ping.fm/vw8TI
# Output tweet: \
# RT, @acfou, The, Ads, Won, Awards, for, Crispin,;, But, Did, Nothing, for, Client, BurgerKing's, Sales,/,Marketshare, -, Big, Surprise, -, http://ping.fm/vw8TI
# Input tweet:
#
# Hey doll! Great I missed True Blood yday boo lol Rt @FrankBanuat78 @jhillstephens Hello Sunshine how are u today? :-)
# Output tweet: \
# Hey, doll,!, Great, I, missed, True, Blood, yday, boo, lol, Rt, @FrankBanuat78, @jhillstephens, Hello, Sunshine, how, are, u, today,?, :-)
#
# Input tweet: \
# Australian artist Pogo made these free songs primarily from sampled audio from Alice In Wonderland. http://www.last.fm/music/Pogo/Wonderland
#
# Output tweet: \
# Australian, artist, Pogo, made, these, free, songs, primarily, from, sampled, audio, from, Alice, In, Wonderland,., http://www.last.fm/music/Pogo/Wonderland
#
# Input tweet: \
# @mppritchard they wanted to sell all the preorders & then sell all of the ones they had in stock to those that just walked in. Can't do both
#
# Output tweet: \
# @mppritchard, they, wanted, to, sell, all, the, preorders, &, then, sell, all, of, the, ones, they, had, in, stock, to, those, that, just, walked, in,., Can't, do, both
#
# Input tweet: \
# Incoming: Frightened Rabbit, Sept. 22 (Tucson): If Fat Cat Records is going to send three great bands from Scot.. http://tinyurl.com/nz6xcv
#
# Output tweet: \
# Incoming,:, Frightened, Rabbit,,, Sept,., 22, (,Tucson,),:, If, Fat, Cat, Records, is, going, to, send, three, great, bands, from, Scot,.,., http://tinyurl.com/nz6xcv
#
# Input tweet: \
# Hey @ginoandfran please greet philip! (GinoandFran live > http://ustre.am/2YyQ)
#
# Output tweet: \
# Hey, @ginoandfran, please, greet, philip,!, (,GinoandFran, live, >, http://ustre.am/2YyQ,)
#
# Input tweet: \
# Ik weet niet wie er achter de T-Mobile iPhone Twitter zit maar ik vind het niet echt 'corporate' taalgebruik... Best vreemd eigenlijk
#
# Output tweet: \
# Ik, weet, niet, wie, er, achter, de, T-Mobile, iPhone, Twitter, zit, maar, ik, vind, het, niet, echt, ',corporate,', taalgebruik,.,.,., Best, vreemd, eigenlijk

# %% [markdown]
#     1. Input tweet
#     ...
#     1. Tokenized tweet
#     ...
#
#     2. Input tweet
#     ...
#     2. Tokenized tweet
#     ...

# %% [markdown]
# ## Task 2. Implement [Byte-Pair Encoding(BPE)](https://arxiv.org/pdf/1508.07909.pdf) Tokenizer (80 points)
#
# ### Task 2.1. Implementation (60 points)
#
# Implement the tokenizer as the BPETokenizer class:
# * Implement `train` method that learns merges and builds the vocabulary of the specified `vocab_size` (25 points).
# * Implement `tokenize` method that should tokenize the text according to the learnt merges (25 points).
#
# Your code should have docstrings and comments (10 points).

# %%
import os
import natsort


def read_corpus(dir_path):
    """
    This is a small function just to create corpus of text

    Args:
        dir_path (_type_): path to the directory that contains tweets

    Returns:
        str: corpus
    """
    files = os.listdir(dir_path)
    files = natsort.natsorted([f for f in files if f.startswith("f")])
    corpus = []
    for file_name in files:
        with open(os.path.join(dir_path, file_name)) as file:
            for line in file:
                corpus.append(line)
    return corpus


corpus = read_corpus("data/")
!

# %%
# This code was inspired by https://arxiv.org/pdf/1508.07909.pdf, http://ethen8181.github.io/machine-learning/deep_learning/subword/bpe.html
from typing import Dict, List, Tuple
from collections import defaultdict
import re
from operator import itemgetter


class BPETokenizer:
    def __init__(self, vocab_size: int) -> None:
        """
        Args:
            vocab_size (int): size of the vocabulary
        EOW end of word
        UNK unknown symbol. For example, we want to tokenize new text, 
        but tokenizer did not see some symbol in training process
        """
        self.vocab_size = vocab_size
        self.EOW = "</w>"
        self.UNK = "</unk>"

    def get_corpus_repr(self, corpus: List[str]):
        """
        This function converts initial token representation
        For example,
        low low low low low-> 'l o w </w>' : 5, 
        lower lower -> 'l o w e r </w>' : 2,

        Args:
            corpus (List[str]): initial corpus

        Returns:
            _type_: converted corpus
        """        
        corpus_repr = defaultdict(int)
        for line in corpus:
            for word in line.split():
                corpus_repr[" ".join(list(word)) + " " + self.EOW] += 1
        return corpus_repr

    def get_pairs_freq(self, corpus_repr: List[str]) -> Dict[Tuple[str, str], int]:
        """
        This function calculates frequency of each pair of symbols

        Args:
            corpus_repr (List[str]): converted corpus

        Returns:
            Dict[Tuple[str, str], int]: dictonary that contains pair of symbols and its frequency
        """             
        pairs = defaultdict(int)
        for word, freq in corpus_repr.items():
            chars = word.split()
            for i in range(len(chars) - 1):
                pairs[(chars[i], chars[i + 1])] += freq
        return pairs

    def get_pairs(self, word:str) -> List[str]:
        """This function returns all pairs of symbols from the given word

        Args:
            word (str): word :)

        Returns:
            List[str]: all pairs
        """        
        pairs = set()
        prev_char = word[0]
        for ch in word[1:]:
            pairs.add((prev_char, ch))
            prev_char = ch
        return pairs

    def merge_tokens(self, best_pair:str, corpus_repr:Dict[str, int]):
        """
        This function merges tokens

        Args:
            best_pair (str): the most frequent pair
            corpus_repr (Dict[str, int]): converted corpus

        Returns:
            Dict[str, int]: converted corpus
        """        

        new_vocab = defaultdict(int)
        pattern = re.escape(" ".join(best_pair))
        replacement = "".join(best_pair)

        for word_in in corpus_repr:
            word_out = re.sub(pattern, replacement, word_in)
            new_vocab[word_out] = corpus_repr[word_in]

        return new_vocab

    def train(self, corpus: List[str]):
        """
        This function trains bpe

        Args:
            corpus (List[str]): corpus

        Returns:
            set: vocabulary
        """        
        corpus_repr = self.get_corpus_repr(corpus)
        self.vocab = set(" ".join(corpus))
        self.bpe_codes = {}
        i = 0
        while len(self.vocab) < self.vocab_size:
            pairs = self.get_pairs_freq(corpus_repr)
            best_pair = max(pairs, key=pairs.get)
            self.vocab.add("".join(best_pair))
            corpus_repr = self.merge_tokens(best_pair, corpus_repr)
            self.bpe_codes[best_pair] = i
            i += 1
        return self.vocab

    def create_new_word(
        self, word: List[str], pair_to_merge: Tuple[str, str]
    ) -> List[str]:
        """
        This function tokenizes word

        Args:
            word (List[str]): word
            pair_to_merge (Tuple[str, str]): 

        Returns:
            List[str]: 
        """        
        first, second = pair_to_merge
        new_word = []
        i = 0
        while i < len(word):
            try:
                j = word.index(first, i)
                new_word.extend(word[i:j])
                i = j
            except ValueError:
                new_word.extend(word[i:])
                break

            if i < len(word) - 1 and word[i + 1] == second:
                new_word.append(first + second)
                i += 2
            else:
                new_word.append(first)
                i += 1
        return new_word

    def encode(self, original_word: str) -> List[str]:
        """
        This function Encodes word

        Args:
            original_word (str)

        Returns:
            List[str]: tokenized word
        """        
        if len(original_word) == 1:
            return original_word

        word = list(original_word)
        word.append(self.EOW)

        while True:
            pairs = self.get_pairs(word)
            bpe_codes_pairs = [
                (pair, self.bpe_codes[pair]) for pair in pairs if pair in self.bpe_codes
            ]
            if not bpe_codes_pairs:
                break

            pair_to_merge = min(bpe_codes_pairs, key=itemgetter(1))[0]
            word = self.create_new_word(word, pair_to_merge)

        return word

    def tokenize(self, text: str) -> List[str]:
        """
        This function tokenizes text

        Args:
            text (str): text

        Returns:
            List[str]: tokens
        """        
        tokens = []
        for word in text.split():
            tokens.extend(self.encode(word))
        return tokens

# %% [markdown]
# ### Task 2.2. Analysis on Tweets Dataset (10 points)
#
# Train the BPE tokenizer on the tweets dataset. Try to tokenize the tweets with the tokenizer of different `vocab_size`. For example, train the BPE tokenizer with `vocab_size` of [base_vocab_size, 250, 500, 750, 1000]. Plot the dependency of the average length of the tokenized tweet by `vocab_size` to analyze how `vocab_size` affects the length of the tokenized tweet on average. Tell what `vocab_size` is preferrable and why.

# %%
import matplotlib.pyplot as plt

# Let's plot

vocab_sizes = [250, 500, 750, 1000]
averages = []
for vocab_size in vocab_sizes:
    tokenizer = BPETokenizer(vocab_size)
    tokenizer.train(corpus)
    sum_ = 0
    for i in range(len(corpus)):
        sum_ += len(tokenizer.tokenize(corpus[i]))
    averages.append(sum_ / len(corpus))

# %%
plt.plot(vocab_sizes, averages)
plt.ylabel('Length of tweet')
plt.xlabel('Vocab size')
plt.show()

# %% [markdown]
# The preferable vocab_size can be determined by analyzing the plot showing the dependency of the average tokenized tweet length on the vocab_size. Generally, we aim to strike a balance between two competing factors:
#
# Tokenization Quality: A smaller vocab_size might result in better tokenization quality because the tokenizer can capture more frequent and meaningful subword units. This leads to a more compact representation of the text, potentially resulting in shorter tokenized sequences.
#
# Coverage: On the other hand, a larger vocab_size allows the tokenizer to represent a wider range of words and subword units, improving the coverage of the vocabulary. This can lead to better generalization and handling of rare or out-of-vocabulary words, but it may also result in longer tokenized sequences due to the increased vocabulary size.
#
# The optimal vocab size would be around 750. This is the point where the average tokenized tweet length starts to stabilize

# %% [markdown]
# ### Task 2.3. Analysis on Dataset of Different Language (10 points)
#
# Find a small dataset of texts in a language other than English. The dataset size should be not greater than several megabytes.
#
# Train the BPE tokenizer on the dataset that you found. Try to tokenize the sentences from this dataset with the tokenizer of different `vocab_size`. Plot the dependency of the average length of the tokenized sentence by `vocab_size` to analyze how `vocab_size` affects the length of the tokenized sentence on average.
#
# Tell how how the average length of the tokenized sentence differs from the average length of the tokenized tweet. Explain why.

# %%
import pandas as pd

data = pd.read_csv('data/rusentitweet_test.csv')
data.head()
# Out:
#                                                 text     label  \
# 0     все мы помним мой ахуй https://t.co/3Kr7yzeYLC      skip
# 1      я считаю это мем года https://t.co/xoVKj5y8Mj  positive
# 2  ян русский на сотку все запятые где надо🤙🏻👍🏻👍🏻...  positive
# 3               бэк дор соти https://t.co/bYCWz4h4Sk      skip
# 4     @daria_karapet * терияки бойз начинает играть*   neutral
#
#                     id
# 0  1318021368932421633
# 1  1218052288964632576
# 2  1212859589592539136
# 3  1306944400824709120
# 4  1321540138334302209

# %%
russian_tweets = data['text'].tolist()

# %%
from tqdm import tqdm


vocab_sizes = [200, 400, 600, 800]
ru_averages = []
for vocab_size in tqdm(vocab_sizes):
    tokenizer = BPETokenizer(vocab_size)
    tokenizer.train(russian_tweets)
    sum_ = 0
    for i in range(len(russian_tweets)):
        sum_ += len(tokenizer.tokenize(russian_tweets[i]))
    ru_averages.append(sum_ / len(russian_tweets))
# Out:
# 100%|██████████| 4/4 [00:26<00:00,  6.53s/it]

# %%
plt.plot(vocab_sizes, ru_averages, label="Russian")
plt.plot(vocab_sizes, averages, label="English")
plt.ylabel('Length of sentence')
plt.xlabel('Vocab size')
plt.legend()
plt.show()

# %% [markdown]
# Russian and English have different language structures and syntactic features. Russian is known for its rich morphology, which means that words often have multiple forms depending on their grammatical role, tense, gender, and case. This richness in morphology can result in longer tokenized sequences for Russian sentences compared to English tweets, which generally have simpler grammatical structures. However, this particular russian dataset contains another type of words. This type of words has shorter length than the average word in English, according to [1]. Therefore, Russian language dataset has less length of the sentences than English.
#
# [1] https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&ved=2ahUKEwikp4bSraaEAxWlgP0HHb-VBwAQFnoECBQQAQ&url=https%3A%2F%2Fpikabu.ru%2Fstory%2Fsrednyaya_dlina_slov_v_raznyikh_yazyikakh_1292937&usg=AOvVaw2uR9SWSOKiH56KneziI0zu&opi=89978449
